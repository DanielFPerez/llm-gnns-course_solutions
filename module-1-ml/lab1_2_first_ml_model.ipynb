# %% [markdown]
# # Lab 1.2 — Training and Evaluating a First ML Model
# **Module I · LLMs & GNNs for Advanced Reasoning over Relational Data**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DanielFPerez/llm-gnns-course_solutions/blob/main/module-1-ml/lab1_2_first_ml_model.ipynb)
#
# ---
#
# ## What you will do
# In this lab you will go through the full supervised-learning workflow:
# 1. **Prepare** the data: encode categoricals, split into train / val / test.
# 2. **Train** a Logistic Regression model.
# 3. **Evaluate** it — first naïvely (accuracy), then properly (confusion matrix, precision, recall, F1).
# 4. `[Extension]` Compare with a Decision Tree and diagnose overfitting.
#
# ## Prerequisites
# You should have completed **Lab 1.1** (or at least be familiar with the Telco Churn dataset).
#
# **Estimated time:** 60–90 min (core) + 20–30 min (extensions)

# %% [markdown]
# ---
# ## 0 · Setup

# %%
import subprocess, sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    print("Running in Google Colab. Cloning the course solutions repository and installing dependencies...")
    subprocess.run(
        ["git", "clone", "--depth", "1",
         "https://github.com/DanielFPerez/llm-gnns-course_solutions.git"],
        check=True,
    )
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-r",
         "llm-gnns-course_solutions/environment/requirements.txt"],
        check=True,
    )
    sys.path.insert(0, "llm-gnns-course_solutions")
else:
    sys.path.insert(0, str(Path("..").resolve()))

print("Setup complete.")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    f1_score,
)

from utils import (
    load_telco_churn,
    plot_class_distribution,
    plot_confusion_matrix,
    plot_training_curves,
    plot_feature_importance,
)
from utils.checks import check_dataframe, check_split, check_model

pd.set_option("display.max_columns", 30)
plt.rcParams["figure.dpi"] = 110
print("Imports OK.")

# %% [markdown]
# ---
# ## 1 · Data preparation
#
# The cleaning steps from Lab 1.1 are provided below — no exercises here. Run this cell to get a clean DataFrame ready for modelling.

# %%
df_raw = load_telco_churn()

df = df_raw.copy()
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce").fillna(0.0)
df["Churn"] = (df["Churn"] == "Yes").astype(int)
df = df.drop(columns=["customerID"])   # ID column carries no signal

print(f"Clean dataset: {df.shape[0]:,} rows × {df.shape[1]} columns")
print(f"Churn rate: {df['Churn'].mean():.1%}")

# %% [markdown]
# ---
# ## 2 · Feature encoding
#
# Most ML models require **numerical inputs**. The Telco dataset has many text columns (`gender`, `Contract`, `PaymentMethod`, …). We need to convert them to numbers.

# %% [markdown]
# ### Exercise 2.1 `[Core]` — One-hot encode the categorical columns
#
# Use `pd.get_dummies()` on the DataFrame (excluding the target column `Churn`). Store the result in `df_encoded`, making sure `Churn` is still a column in it.
#
# **Tip:** `pd.get_dummies(df, drop_first=True)` automatically handles all `object` columns and drops one dummy per category to avoid collinearity.

# %%
# --- SOLUTION ---
# Separate target before encoding to avoid accidentally one-hot encoding it
y_series = df["Churn"]
df_features = df.drop(columns=["Churn"])

df_encoded_features = pd.get_dummies(df_features, drop_first=True)
df_encoded = pd.concat([df_encoded_features, y_series], axis=1)

print(f"Columns before encoding: {df_features.shape[1]}")
print(f"Columns after encoding:  {df_encoded_features.shape[1]}")
df_encoded.head(3)

# %%
check_dataframe(
    "2.1", df_encoded,
    min_rows=7000,
    required_cols=["Churn", "tenure", "MonthlyCharges"],
)

# %% [markdown]
# ---
# ## 3 · Train / Validation / Test split
#
# We split the data **three ways**:
# - **Train (70%):** the model learns from this.
# - **Validation (15%):** we tune and compare models here, without touching the test set.
# - **Test (15%):** held out until the very end — our unbiased estimate of real-world performance.
#
# We use `stratify=y` to preserve the ~73/27 class ratio in all three sets.

# %% [markdown]
# ### Exercise 2.2 `[Core]` — Split the data
#
# Create `X_train`, `X_val`, `X_test`, `y_train`, `y_val`, `y_test` with a 70/15/15 split. Use `random_state=42` and `stratify=y` throughout.
#
# **Tip:** Do it in two steps — first split off the test set, then split the remaining 85% into train and val.

# %%
# --- SOLUTION ---
X = df_encoded.drop(columns=["Churn"])
y = df_encoded["Churn"]

# Step 1: hold out 15% as test
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.15, random_state=42, stratify=y
)

# Step 2: from the remaining 85%, hold out 15/85 ≈ 17.6% as val → gives ~15% of total
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.15 / 0.85, random_state=42, stratify=y_temp
)

print(f"Train : {len(X_train):,} rows ({len(X_train)/len(X):.1%})")
print(f"Val   : {len(X_val):,} rows ({len(X_val)/len(X):.1%})")
print(f"Test  : {len(X_test):,} rows ({len(X_test)/len(X):.1%})")

# %%
check_split("2.2", X_train, X_val, X_test, y_train, y_val, y_test)

# %% [markdown]
# ---
# ## 4 · Training a Logistic Regression model
#
# **Logistic Regression** is a strong, interpretable baseline for binary classification. Despite its name, it is a *classification* algorithm: it outputs the probability that a sample belongs to class 1 (Churn) and applies a threshold (default: 0.5).
#
# Because features have very different scales (`tenure` goes 0–72, `MonthlyCharges` goes 18–119), we first **standardise** them: subtract the mean and divide by the standard deviation. This is required for Logistic Regression to converge well.
#
# > **Important:** Fit the scaler **only on the training set**, then apply it to val and test. Fitting on all data would let information from the future leak into training — a form of data leakage.

# %% [markdown]
# ### Exercise 2.3 `[Core]` — Scale features and train the model
#
# 1. Create a `StandardScaler` and fit it on `X_train`. Transform `X_train`, `X_val`, and `X_test`.
# 2. Create a `LogisticRegression(max_iter=500, random_state=42)` and train it on the scaled training data.
# 3. Store the fitted model in a variable called `lr`.

# %%
# 1. Scale features (fit only on train)
scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_val_sc   = scaler.transform(X_val)
X_test_sc  = scaler.transform(X_test)

# %%
# --- SOLUTION ---
# 2. Initialize andTrain Logistic Regression
lr = LogisticRegression(max_iter=500, random_state=42)
lr.fit(X_train_sc, y_train)

print("Model trained. Coefficients shape:", lr.coef_.shape)

# %% [markdown]
# ---
# ## 5 · Evaluation
#
# Now we measure how well the model performs. We will evaluate it on the **validation set** (never the test set — that is saved for the end).

# %% [markdown]
# ### Exercise 2.4 `[Core]` — Accuracy: the misleading metric
#
# Compute the accuracy of `lr` on the validation set. Then compute what accuracy a **dummy classifier** that always predicts the majority class (No Churn = 0) would achieve.
#
# Do the two numbers feel close? Why is accuracy alone not enough here?

# %%
# --- SOLUTION ---
y_pred_lr = lr.predict(X_val_sc)

acc_model = accuracy_score(y_val, y_pred_lr)
acc_dummy = accuracy_score(y_val, np.zeros(len(y_val), dtype=int))  # always predicts 0

# %%
print(f"Logistic Regression accuracy : {acc_model:.3f}")
print(f"Dummy (always 'No Churn')    : {acc_dummy:.3f}")
print()
print("The gap is real, but not as impressive as it looks.")
print("The dummy already gets 73% correct by exploiting the imbalance.")
print("→ We need metrics that measure performance on the minority class (Churn=1).")

# %% [markdown]
# ### Exercise 2.5 `[Core]` — Confusion matrix
#
# Plot the confusion matrix for the Logistic Regression predictions on the validation set. Use the `plot_confusion_matrix` helper from `utils`.
#
# > **Reminder (Lecture, Slide 18):**
# > - **True Positive (TP):** predicted Churn, actually Churn.
# > - **True Negative (TN):** predicted No Churn, actually No Churn.
# > - **False Positive (FP):** predicted Churn, actually No Churn (false alarm).
# > - **False Negative (FN):** predicted No Churn, actually Churn (missed churner — costly!).

# %%
# --- SOLUTION ---
cm = confusion_matrix(y_val, y_pred_lr)
plot_confusion_matrix(cm, class_names=["No Churn", "Churn"]);
print(f"\nTN={cm[0,0]}, FP={cm[0,1]}, FN={cm[1,0]}, TP={cm[1,1]}")

# %% [markdown]
# > **What to notice:** The model catches a decent fraction of churners (TP) but also produces many false negatives (FN) — actual churners predicted as staying. In a real deployment, every FN is a lost customer. This is why recall matters more than accuracy here.

# %% [markdown]
# ### Exercise 2.6 `[Core]` — Precision, Recall, and F1
#
# Print the full `classification_report` for the Logistic Regression on the validation set. Identify:
# - The **recall** for class 1 (Churn) — what fraction of actual churners did we catch?
# - The **F1-score** for class 1 — the harmonic mean of precision and recall.

# %%
# --- SOLUTION ---
print(classification_report(y_val, y_pred_lr, target_names=["No Churn", "Churn"]))

# %%
check_model("2.6", lr, X_val_sc, y_val, min_f1=0.4)

# %% [markdown]
# > **Interpretation guide:**
# > - **Precision (Churn):** of everyone we flagged as likely to churn, what fraction actually did? Low precision → many false alarms (wasted retention campaigns).
# > - **Recall (Churn):** of everyone who actually churned, what fraction did we catch? Low recall → missed churners (lost revenue).
# > - **F1 (Churn):** the single number that balances both. Use this to compare models.

# %% [markdown]
# ---
# ## 6 · `[Extension]` Comparing models: Decision Tree
#
# Logistic Regression is linear. A **Decision Tree** can capture non-linear patterns (e.g., "high charges AND short tenure → likely to churn"). Let's compare.

# %% [markdown]
# ### Exercise 2.7 `[Extension]` — Train a Decision Tree and compare F1
#
# 1. Train a `DecisionTreeClassifier(random_state=42)` on the *unscaled* training data (decision trees don't need scaling).
# 2. Print the classification report on the validation set.
# 3. Compare the **Churn F1-score** with Logistic Regression. Which is better? Why might that be?

# %%
# --- SOLUTION ---
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_val)

# %%
print("=== Decision Tree ===")
print(classification_report(y_val, y_pred_dt, target_names=["No Churn", "Churn"]))

f1_lr = f1_score(y_val, y_pred_lr, pos_label=1)
f1_dt = f1_score(y_val, y_pred_dt, pos_label=1)

print(f"\nChurn F1 — Logistic Regression : {f1_lr:.3f}")
print(f"Churn F1 — Decision Tree       : {f1_dt:.3f}")
print(f"Winner: {'Logistic Regression' if f1_lr >= f1_dt else 'Decision Tree'}")

# %% [markdown]
# > **Common finding:** The unconstrained Decision Tree often achieves near-perfect training accuracy but lower validation performance than Logistic Regression. This is **overfitting** — the tree memorises the training data, including its noise, and fails to generalise. We diagnose this properly in Exercise 2.8.

# %% [markdown]
# ### Exercise 2.8 `[Extension]` — Diagnosing overfitting with learning curves
#
# Train the Decision Tree on increasingly large subsets of the training data and record both **train F1** and **val F1** at each size. A large gap between the two curves signals overfitting.
#
# Then try limiting the tree depth (`max_depth=5`) and see if the gap closes.

# %%
# --- SOLUTION ---
train_sizes = np.linspace(0.10, 1.0, 10)
train_f1s, val_f1s = [], []

for frac in train_sizes:
    n = max(50, int(frac * len(X_train)))
    X_sub, y_sub = X_train.iloc[:n], y_train.iloc[:n]

    m = DecisionTreeClassifier(random_state=42)
    m.fit(X_sub, y_sub)

    train_f1s.append(f1_score(y_sub, m.predict(X_sub), pos_label=1))
    val_f1s.append(f1_score(y_val, m.predict(X_val), pos_label=1))

plot_training_curves(
    train_f1s, val_f1s,
    metric="Churn F1",
    title="Learning curve — Decision Tree (unconstrained)",
)
plt.show()

# %%
# Now with max_depth=5 to reduce overfitting
train_f1s_p, val_f1s_p = [], []

for frac in train_sizes:
    n = max(50, int(frac * len(X_train)))
    X_sub, y_sub = X_train.iloc[:n], y_train.iloc[:n]

    m = DecisionTreeClassifier(max_depth=5, random_state=42)
    m.fit(X_sub, y_sub)

    train_f1s_p.append(f1_score(y_sub, m.predict(X_sub), pos_label=1))
    val_f1s_p.append(f1_score(y_val, m.predict(X_val), pos_label=1))

plot_training_curves(
    train_f1s_p, val_f1s_p,
    metric="Churn F1",
    title="Learning curve — Decision Tree (max_depth=5)",
)
plt.show()

# %% [markdown]
# > **Key takeaway:** With `max_depth=5` the train/val gap shrinks significantly — the curves converge. This is **regularisation**: constraining the model's complexity so it generalises better. We have just manually implemented the core idea behind model selection.

# %% [markdown]
# ---
# ## 7 · `[Extension]` Feature importance

# %% [markdown]
# ### Exercise 2.9 `[Extension]` — Which features does the model rely on most?
#
# Extract the feature importances from the Decision Tree (attribute: `.feature_importances_`) and visualise the top 15 using `plot_feature_importance` from `utils`. Do the top features match the correlations you found in Lab 1.1?

# %%
# --- SOLUTION ---
dt_tuned = DecisionTreeClassifier(max_depth=5, random_state=42)
dt_tuned.fit(X_train, y_train)

plot_feature_importance(
    dt_tuned.feature_importances_,
    feature_names=list(X_train.columns),
    top_n=15,
    title="Top 15 feature importances — Decision Tree (max_depth=5)",
);

# %% [markdown]
# ---
# ## 8 · `[Extension]` Multi-Layer Perceptron
#
# So far we have used **linear** (Logistic Regression) and **tree-based** (Decision Tree) models. A **Multi-Layer Perceptron (MLP)** adds one or more hidden layers of learned representations between the input and the output — the simplest form of a deep neural network.
#
# This section introduces MLPs in two ways:
# - **Exercise 2.10:** the scikit-learn `MLPClassifier` — same API as LR/DT, minimal friction.
# - **Exercise 2.11:** a PyTorch `nn.Module` with a manual training loop — the exact pattern you will use for GCN and GAT in Module III.

# %% [markdown]
# ### Exercise 2.10 `[Extension]` — MLP with scikit-learn
#
# Train an `MLPClassifier` with two hidden layers (64 and 32 units) on the scaled training data. Print the classification report on the validation set and compare the Churn F1 with Logistic Regression and the Decision Tree.

# %%
# --- SOLUTION ---
from sklearn.neural_network import MLPClassifier

mlp_sk = MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=300, random_state=42)
mlp_sk.fit(X_train_sc, y_train)

y_pred_mlp_sk = mlp_sk.predict(X_val_sc)

print("=== MLP (scikit-learn) ===")
print(classification_report(y_val, y_pred_mlp_sk, target_names=["No Churn", "Churn"]))

f1_mlp_sk = f1_score(y_val, y_pred_mlp_sk, pos_label=1)
print(f"Churn F1 comparison:")
print(f"  Logistic Regression : {f1_lr:.3f}")
print(f"  Decision Tree       : {f1_dt:.3f}")
print(f"  MLP (sklearn)       : {f1_mlp_sk:.3f}")

# %% [markdown]
# > **What to notice:** The MLP typically matches or edges out Logistic Regression on Churn F1 because it can model non-linear interactions between features (e.g., the combination of high charges *and* short tenure). The sklearn API is identical to what we used before — `.fit()`, `.predict()`, `.score()` — so the only change is the model class.

# %% [markdown]
# ### Exercise 2.11 `[Extension]` — MLP with PyTorch
#
# Now we implement the same network from scratch using **PyTorch**. This introduces the training loop pattern that powers every deep-learning model in this course (including GCN and GAT in Module III):
#
# 1. Define the model as an `nn.Module`.
# 2. Convert data to `torch.Tensor` and wrap in a `DataLoader` for mini-batch iteration.
# 3. For each epoch: forward pass → compute loss → `.backward()` → optimizer step.
# 4. Track training and validation loss to diagnose learning behaviour.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

class ChurnMLP(nn.Module):
    def __init__(self, input_dim: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1),   # raw logit — BCEWithLogitsLoss handles the sigmoid
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x).squeeze(1)

# Convert numpy arrays → tensors
X_train_t = torch.tensor(X_train_sc, dtype=torch.float32)
y_train_t = torch.tensor(y_train.values, dtype=torch.float32)
X_val_t   = torch.tensor(X_val_sc,   dtype=torch.float32)
y_val_t   = torch.tensor(y_val.values, dtype=torch.float32)

train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), batch_size=64, shuffle=True)

print(f"Input dimension : {X_train_sc.shape[1]} features")
print(f"Batches / epoch : {len(train_loader)}")
print(ChurnMLP(X_train_sc.shape[1]))

# %%
# --- SOLUTION ---
EPOCHS = 60

torch_mlp = ChurnMLP(input_dim=X_train_sc.shape[1])
optimizer  = torch.optim.Adam(torch_mlp.parameters(), lr=1e-3)
criterion  = nn.BCEWithLogitsLoss()

train_losses, val_losses = [], []

for epoch in range(EPOCHS):
    # ── training pass ──────────────────────────────────────────────────────────
    torch_mlp.train()
    running_loss = 0.0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        loss = criterion(torch_mlp(X_batch), y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * len(X_batch)
    train_losses.append(running_loss / len(X_train_t))

    # ── validation loss ─────────────────────────────────────────────────────────
    torch_mlp.eval()
    with torch.no_grad():
        val_losses.append(criterion(torch_mlp(X_val_t), y_val_t).item())

plot_training_curves(
    train_losses, val_losses,
    metric="BCE Loss",
    title="MLP (PyTorch) — loss curves",
)
plt.gca().set_xlabel("Epoch")
plt.show()
print(f"Train loss: {train_losses[-1]:.4f}  |  Val loss: {val_losses[-1]:.4f}")

# %%
torch_mlp.eval()
with torch.no_grad():
    val_probs = torch.sigmoid(torch_mlp(X_val_t)).numpy()

y_pred_torch = (val_probs > 0.5).astype(int)

print("=== MLP (PyTorch) ===")
print(classification_report(y_val, y_pred_torch, target_names=["No Churn", "Churn"]))

f1_torch = f1_score(y_val, y_pred_torch, pos_label=1)
print(f"\nChurn F1 — all models:")
print(f"  Logistic Regression : {f1_lr:.3f}")
print(f"  Decision Tree       : {f1_dt:.3f}")
print(f"  MLP (sklearn)       : {f1_mlp_sk:.3f}")
print(f"  MLP (PyTorch)       : {f1_torch:.3f}")

# %% [markdown]
# > **Key takeaways:**
# > - The loss curves show the model learning epoch by epoch — train loss decreases steadily and val loss tracks it closely, confirming no severe overfitting.
# > - The PyTorch MLP achieves comparable F1 to the sklearn version; the difference (if any) comes from the explicit Dropout regularisation and mini-batch shuffling.
# > - **The training loop structure here is identical to what you will write in Module III** for a Graph Convolutional Network — the only change is that `X_batch` will be replaced by a PyG `Data` object and the model will be a `GCNConv`-based `nn.Module`. Recognising this pattern now will make Module III much easier to follow.

# %% [markdown]
# ### Exercise 2.12 `[Extension]` — The effect of regularisation
#
# We will train two networks side by side to make regularisation visible:
#
# | Model | Dropout | L2 (weight decay) |
# |---|---|---|
# | **Baseline** | ✗ | ✗ |
# | **Regularised** | ✓ (p = 0.3) | ✓ (λ = 1e-4) |
#
# Plot their train vs. val loss curves and compare the final Churn F1. A large gap between the train and val curves of the baseline signals overfitting; regularisation should close that gap.

# %%
# --- SOLUTION ---

# ── Unregularised baseline (no dropout, no weight decay) ───────────────────────
class ChurnMLPBaseline(nn.Module):
    def __init__(self, input_dim: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64), nn.ReLU(),
            nn.Linear(64, 32),        nn.ReLU(),
            nn.Linear(32, 1),
        )
    def forward(self, x):
        return self.net(x).squeeze(1)

# Shared training helper to avoid repeating the loop
def run_training(model, optimizer, epochs=60):
    crit = nn.BCEWithLogitsLoss()
    tr_losses, va_losses = [], []
    for _ in range(epochs):
        model.train()
        running = 0.0
        for X_b, y_b in train_loader:
            optimizer.zero_grad()
            loss = crit(model(X_b), y_b)
            loss.backward()
            optimizer.step()
            running += loss.item() * len(X_b)
        tr_losses.append(running / len(X_train_t))
        model.eval()
        with torch.no_grad():
            va_losses.append(crit(model(X_val_t), y_val_t).item())
    return tr_losses, va_losses

input_dim = X_train_sc.shape[1]

mlp_base = ChurnMLPBaseline(input_dim)
tr_base, va_base = run_training(mlp_base, torch.optim.Adam(mlp_base.parameters(), lr=1e-3))

# ── Regularised: Dropout(0.3) + L2 weight decay ───────────────────────────────
mlp_reg = ChurnMLP(input_dim)   # already has Dropout(0.3) from Exercise 2.11
tr_reg, va_reg = run_training(
    mlp_reg,
    torch.optim.Adam(mlp_reg.parameters(), lr=1e-3, weight_decay=1e-4),
)

print("Both models trained.")

# %%
# ── Side-by-side loss curves ───────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=True)

for ax, tr, va, title in zip(
    axes,
    [tr_base, tr_reg],
    [va_base, va_reg],
    ["No regularisation", "Dropout + L2 weight decay"],
):
    epochs = range(1, len(tr) + 1)
    ax.plot(epochs, tr, label="Train")
    ax.plot(epochs, va, label="Validation", linestyle="--")
    ax.set_title(title)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("BCE Loss")
    ax.legend()
    ax.spines[["top", "right"]].set_visible(False)

plt.suptitle("Effect of regularisation on MLP training curves", fontweight="bold")
plt.tight_layout()
plt.show()

# ── F1 comparison ──────────────────────────────────────────────────────────────
print(f"{'Model':<30}  Train-Val gap (final)  Churn F1")
print("-" * 60)
for name, model, tr, va in [
    ("Baseline (no reg)",          mlp_base, tr_base, va_base),
    ("Regularised (dropout + L2)", mlp_reg,  tr_reg,  va_reg),
]:
    model.eval()
    with torch.no_grad():
        preds = (torch.sigmoid(model(X_val_t)) > 0.5).int().numpy()
    f1 = f1_score(y_val, preds, pos_label=1)
    gap = va[-1] - tr[-1]
    print(f"{name:<30}  {gap:+.4f}                 {f1:.3f}")

# %% [markdown]
# > **What to notice:**
# > - **Loss curves:** The baseline's validation loss typically plateaus or rises while its training loss keeps falling — the classic overfitting signature. The regularised model's two curves stay much closer together throughout training.
# > - **Train-Val gap:** A positive gap (val > train) at the end of training confirms the baseline is overfitting; regularisation shrinks this gap.
# > - **Dropout** randomly zeros 30 % of activations during each forward pass, preventing neurons from co-adapting to specific training examples.
# > - **L2 weight decay** (the `weight_decay` argument in Adam) adds a penalty proportional to the squared magnitude of every weight, pushing the network towards smaller, smoother solutions.
# > - The two techniques are complementary and are routinely combined in practice — including in the GCN and GAT models you will train in Module III.

# %% [markdown]
# ---
# ## 9 · Final evaluation on the test set
#
# We have been evaluating everything on the **validation set**. Now that we have chosen our best model (Logistic Regression, based on the validation F1), we run it exactly **once** on the test set to get an unbiased estimate of real-world performance.
#
# > Do this only once. If you look at the test set repeatedly and adjust the model based on it, you are effectively overfitting to the test set.

# %%
y_pred_test = lr.predict(X_test_sc)

print("=== Final evaluation — Logistic Regression on TEST set ===")
print(classification_report(y_pred_test, y_test, target_names=["No Churn", "Churn"]))

cm_test = confusion_matrix(y_test, y_pred_test)
plot_confusion_matrix(cm_test, class_names=["No Churn", "Churn"], title="Confusion matrix — Test set");

# %% [markdown]
# ---
# ## Summary
#
# | Step | What we did | Key lesson |
# |---|---|---|
# | Feature encoding | `pd.get_dummies` | ML needs numbers; text must be encoded |
# | Train/val/test split | 70/15/15, stratified | Never touch the test set until the end |
# | Feature scaling | `StandardScaler` (fit on train only) | Prevents data leakage; required for LR |
# | Accuracy | ~81% — looked good | 73% is free from the majority class |
# | Confusion matrix | Revealed many FNs | Missed churners are a real business cost |
# | Precision / Recall / F1 | Proper evaluation | F1 balances both sides of the trade-off |
# | Decision Tree `[Ext]` | Higher train, lower val accuracy | Classic overfitting — cured by `max_depth` |
# | Feature importance `[Ext]` | `Contract`, `tenure`, `MonthlyCharges` dominate | Matches the EDA intuition from Lab 1.1 |
# | MLP sklearn `[Ext]` | `MLPClassifier(64, 32)` — same API as LR | Non-linear model, minimal extra code |
# | MLP PyTorch `[Ext]` | `nn.Module` + manual training loop | The exact pattern used for GCN/GAT in Module III |
# | Regularisation `[Ext]` | Dropout + L2 weight decay vs baseline | Closes the train/val gap; same techniques used in GNNs |
#
# ---
#
# ## Connection to the final project
#
# You now have the complete Module I workflow: load → clean → encode → split → train → evaluate. In the final project, you will apply this same workflow to a dataset of your choice. Starting in **Module II**, we will replace Logistic Regression with an LLM and augment it with a retrieval layer — and eventually (Module IV) with a Graph Neural Network.
#
# > **The ML fundamentals you practised today are not a detour — they are the foundation everything else builds on.**
